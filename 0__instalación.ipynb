# %% [markdown]
# # Curso de Web Scraping
#
# <img src="https://yaelmanuel.com/wp-content/uploads/2021/12/platzi-banner-logo-matematicas.png" width="500px">
#
# ---

# %% [markdown]
# ## 0) Instalación de Librerías

# %% [markdown]
# **Request**

# %%
# !pip3 install requests
# Out:
# Requirement already satisfied: requests in C:\Users\diego\AppData\Local\Programs\Python\Python312\Lib\site-packages (2.32.5)
# Requirement already satisfied: charset_normalizer<4,>=2 in C:\Users\diego\AppData\Local\Programs\Python\Python312\Lib\site-packages (from requests) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in C:\Users\diego\AppData\Local\Programs\Python\Python312\Lib\site-packages (from requests) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in C:\Users\diego\AppData\Local\Programs\Python\Python312\Lib\site-packages (from requests) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in C:\Users\diego\AppData\Local\Programs\Python\Python312\Lib\site-packages (from requests) (2026.1.4)

# %% [markdown]
# **BeautifulSoup**

# %%
# !pip3 install beautifulsoup4
# Out:
# Requirement already satisfied: beautifulsoup4 in C:\Users\diego\AppData\Local\Programs\Python\Python312\Lib\site-packages (4.14.3)
# Requirement already satisfied: soupsieve>=1.6.1 in C:\Users\diego\AppData\Local\Programs\Python\Python312\Lib\site-packages (from beautifulsoup4) (2.8.3)
# Requirement already satisfied: typing-extensions>=4.0.0 in C:\Users\diego\AppData\Local\Programs\Python\Python312\Lib\site-packages (from beautifulsoup4) (4.15.0)
